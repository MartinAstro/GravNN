# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_1000000_study.data"
# file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_1000000_exp_norm_study.data"
#file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\temp.data"
file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_1000000_PINN_study.data"
#file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_1000000_Rand_Study.data"

#file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_1000000_PINN_study_opt.data"



# Small Datasets
#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_10000_rand_study.data'
#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_10000_rand_spherical_study.data'

# file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_10000_exp_study.data'

#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_10000_rand_PINN_study.data'
# file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_10000_exp_PINN_study.data'

# file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_10000_rand_spherical_study.data'


# Eros Datasets

#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_100000_rand_eros_study.data'
#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_100000_rand_eros_PINN_study.data'

#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\temp_spherical.data'
#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\new_pinn_constraints.data'

file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\new_temp.data'
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\hyperparameter_v3.data'
#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_1000000_all.data' # Generalization
#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\N_1000000_Rand_Study.data' # Compactness

#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\deeper_networks9.data' # Generalization
#file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\old_test.data' # Generalization




df = pd.read_pickle(file_name)

# %%
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\sh_stats_Brillouin.data' # Generalization




stats = pd.read_pickle(file_name)
stats.iloc[30:70]
# Out:
#      rse_mean   rse_std  rse_median  sigma_2_mean  sigma_2_std  \
# deg
# 32   0.000231  0.000288    0.000141      0.001281     0.000525
# 33   0.000230  0.000287    0.000140      0.001277     0.000525
# 34   0.000229  0.000286    0.000140      0.001271     0.000525
# 35   0.000229  0.000285    0.000140      0.001267     0.000525
# 36   0.000228  0.000285    0.000139      0.001262     0.000524
# 37   0.000227  0.000284    0.000139      0.001257     0.000524
# 38   0.000227  0.000283    0.000139      0.001253     0.000523
# 39   0.000226  0.000283    0.000138      0.001248     0.000522
# 40   0.000225  0.000282    0.000137      0.001245     0.000521
# 41   0.000225  0.000281    0.000137      0.001240     0.000521
# 42   0.000224  0.000280    0.000136      0.001236     0.000521
# 43   0.000223  0.000280    0.000136      0.001232     0.000521
# 44   0.000223  0.000279    0.000135      0.001227     0.000521
# 45   0.000223  0.000278    0.000135      0.001222     0.000520
# ...

# %%
df.columns
# Out:
# Index(['Brillouin_max_error', 'Brillouin_param_rse_mean',
#        'Brillouin_param_rse_median', 'Brillouin_param_sigma_2_c_mean',
#        'Brillouin_param_sigma_2_c_median', 'Brillouin_param_sigma_2_mean',
#        'Brillouin_param_sigma_2_median', 'Brillouin_param_sigma_3_c_mean',
#        'Brillouin_param_sigma_3_c_median', 'Brillouin_param_sigma_3_mean',
#        'Brillouin_param_sigma_3_median', 'Brillouin_rse_mean',
#        'Brillouin_rse_median', 'Brillouin_rse_std', 'Brillouin_sigma_2_c_mean',
#        'Brillouin_sigma_2_c_median', 'Brillouin_sigma_2_c_std',
#        'Brillouin_sigma_2_mean', 'Brillouin_sigma_2_median',
#        'Brillouin_sigma_2_std', 'Brillouin_sigma_3_c_mean',
#        'Brillouin_sigma_3_c_median', 'Brillouin_sigma_3_c_std',
#        'Brillouin_sigma_3_mean', 'Brillouin_sigma_3_median',
#        'Brillouin_sigma_3_std', 'N_dist', 'N_train', 'N_val', 'PINN_flag',
#        'a_transformer', 'acc_noise', 'activation', 'analytic_truth', 'basis',
# ...

# %% [markdown]
# # Read Statistics

# %%
sub_df = df[df['params'] == 3083]
sub_df[['params', 'epochs', 'dropout', 'activation', 'batch_size', 'N_train', 'Brillouin_param_rse_mean', 'Brillouin_param_sigma_2_mean', ]].sort_values(by='Brillouin_param_rse_mean', ascending=False)#, 'Brillouin_sh_diff_median')
#df[['params', 'epochs', 'PINN_flag', 'dropout', 'batch_size', 'N_train','radius_max', 'Brillouin_sh_rse_mean', 'Brillouin_sh_sigma_2_mean', ]].sort_values(by='Brillouin_sh_rse_mean', ascending=False)#, 'Brillouin_sh_diff_median']
# Out:
#                           params  epochs  dropout     activation  batch_size  \
# timetag
# Sun Feb 28 11:40:30 2021    3083    7500      0.0           tanh        8196
# Thu Feb 25 22:31:44 2021    3083    5000      0.0           tanh        8196
# Sun Feb 28 09:55:41 2021    3083    7500      0.0           tanh        8196
# Wed Feb 24 22:13:08 2021    3083    2500      0.0           tanh        8196
# Sun Feb 28 13:53:32 2021    3083    7500      0.0           tanh       32768
# ...                          ...     ...      ...            ...         ...
# Fri Feb 26 09:11:39 2021    3083    5000      0.1  bent_identity      131072
# Fri Feb 26 09:01:31 2021    3083    5000      0.1           tanh      131072
# Fri Feb 26 08:52:38 2021    3083    5000      0.1  bent_identity      131072
# Mon Mar  1 08:02:52 2021    3083    7500      0.1  bent_identity      131072
# Mon Mar  1 07:09:23 2021    3083    7500      0.1  bent_identity       32768
#
# ...

# %%
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\deeper_networks9.data'
df_deeper2 = pd.read_pickle(file_name)
df_deeper2[['params', 'layers', 'batch_size', 'N_train', 'Brillouin_param_rse_median', 'Brillouin_param_sigma_2_median', 'Brillouin_rse_median']].sort_values(by='Brillouin_param_rse_median', ascending=False)#, 'Brillouin_sh_diff_median']
# Out:
#                           params  \
# timetag
# Mon Mar  8 07:13:54 2021   47843
# Mon Mar  8 12:28:46 2021   46691
# Sun Mar  7 21:10:33 2021   13955
# Mon Mar  8 00:22:57 2021   12323
# Mon Mar  8 03:34:42 2021    3263
#
#                                                                      layers  \
# timetag
# Mon Mar  8 07:13:54 2021  [3, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40...
# Mon Mar  8 12:28:46 2021  [3, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32...
# Sun Mar  7 21:10:33 2021  [3, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32...
# Mon Mar  8 00:22:57 2021  [3, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20...
# Mon Mar  8 03:34:42 2021  [3, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10...
#
#                           batch_size  N_train  Brillouin_param_rse_median  \
# timetag
# Mon Mar  8 07:13:54 2021        2048  1950000                        93.0
# Mon Mar  8 12:28:46 2021        2048  1950000                        92.0
# ...

# %% [markdown]
# # Scatter Matrix

# %%
sub_df = df[['params', 'batch_size', 'N_train', 'Brillouin_param_rse_median', 'Brillouin_param_sigma_2_median', ]].sort_values(by='Brillouin_param_rse_median', ascending=False)#, 'Brillouin_sh_diff_median']
df.plot.scatter('params', 'Brillouin_rse_median', logy=True)
df.plot.scatter('params', 'Brillouin_param_rse_median', logy=True)
df.plot.scatter('N_train', 'Brillouin_param_rse_median', logy=True)
df.plot.scatter('Brillouin_rse_median', 'Brillouin_param_rse_median', logy=True, logx=True)
# Out:
# <AxesSubplot:xlabel='Brillouin_rse_median', ylabel='Brillouin_param_rse_median'>

# %% [markdown]
# # Find Best Network for Each Param Count

# %%
best_20 = df[df['num_units'] == 20].sort_values('Brillouin_rse_median', ascending=True).iloc[0]['Brillouin_param_rse_median']
best_40 = df[df['num_units'] == 40].sort_values('Brillouin_rse_median', ascending=True).iloc[0]['Brillouin_param_rse_median']
best_80 = df[df['num_units'] == 80].sort_values('Brillouin_rse_median', ascending=True).iloc[0]['Brillouin_param_rse_median']

best_20 = df[df['num_units'] == 20].sort_values('Brillouin_sigma_2_median', ascending=True).iloc[0]['Brillouin_param_sigma_2_median']
best_40 = df[df['num_units'] == 40].sort_values('Brillouin_sigma_2_median', ascending=True).iloc[0]['Brillouin_param_sigma_2_median']
best_80 = df[df['num_units'] == 80].sort_values('Brillouin_sigma_2_median', ascending=True).iloc[0]['Brillouin_param_sigma_2_median']


print(best_20)
print(best_40)
print(best_80)

# print(best_20*(best_20+1))
# print(best_40*(best_40+1))
# print(best_80*(best_80+1))
# Out:
# 53.0
# 94.0
# 116.0
# 2862.0
# 8930.0
# 13572.0

# %% [markdown]
# # Modify Dataframe

# %%
df.drop(index=df.index[2:], inplace=True)
file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\Dataframes\\new_pinn_constraints.data"
original_df = pd.read_pickle(file_name)
df.to_pickle(file_name)

# %% [markdown]
# # Format Distrubtion Dataframe Columns

# %%
pd.set_option('mode.chained_assignment','raise')

from GravNN.Trajectories.ExponentialDist import ExponentialDist
from GravNN.Trajectories.GaussianDist import GaussianDist
from GravNN.Trajectories.RandomDist import RandomDist
from GravNN.CelestialBodies.Planets import Earth

mask = df['distribution'] == RandomDist
df.loc[mask, ('invert', 'scale_parameter')]=None


mask = df['distribution'] == ExponentialDist
df.loc[mask, ('mu', 'sigma')]=None

df['N_dist'] = 1000000
df['planet'] = Earth()

# %%
df_rand = df[df['radius_max'] == 6798136.6]
df_rand = df_rand[df_rand['radius_min'] == 6378136.6]

# %%
df_rand.to_pickle("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\N_1000000_Rand_Study.data")

# %%
file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\N_1000000_Rand_Study.data"
df_rand = pd.read_pickle(file_name)

file_name = "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\N_1000000_exp_norm_study.data"
df_exp = pd.read_pickle(file_name)
df_exp['grav_file'] = Earth().sh_hf_file
df_exp.rename(columns={"Brillouin_sh_diff_mean":"Brillouin_sh_rse_mean", "Brillouin_sh_diff_median":"Brillouin_sh_rse_median"},inplace=True)#, "Brillouin_diff_std":"Brillouin_rse_diff"}, inplace=True)
df_rand.drop(columns=["Brillouin_sh_diff_mean", "Brillouin_sh_diff_median"], axis=1,inplace=True)

df = pd.concat([df_rand, df_exp])
df.to_pickle( "C:\\Users\\John\\Documents\\Research\\ML_Gravity\\N_1000000_all.data")

# %%
df['params'][400]
# Out:
# 45923

# %%
df_exp.to_pickle("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\N_1000000_exp_norm_study.data")

# %%
# df_rand.drop(columns={'Brillouin_diff_mean', 'Brillouin_diff_median', 'Brillouin_diff_std', 'LEO_diff_mean', 'LEO_diff_median', 'LEO_diff_std'}, inplace=True)
# df_rand.rename(columns={"Brillouin_diff_mean":"Brillouin_rse_mean", "Brillouin_diff_median":"Brillouin_rse_median", "Brillouin_diff_std":"Brillouin_rse_diff"}, inplace=True)
# df_rand.rename(columns={"LEO_diff_mean":"LEO_rse_mean", "LEO_diff_median":"LEO_rse_median", "LEO_diff_std": "LEO_rse_diff"}, inplace=True)

# %%
 np.setdiff1d( df_rand.columns.values, df_exp.columns.values)
# Out:
# array(['Brillouin_rse_diff', 'Brillouin_sh_rse_mean',
#        'Brillouin_sh_rse_median', 'LEO_rse_diff', 'LEO_sh_rse_mean',
#        'LEO_sh_rse_median'], dtype=object)

# %%
import pandas as pd
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\poly_stats_eros_surface.data'
df = pd.read_pickle(file_name)

# %%
import pandas as pd
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Data\\speed_results.data'
df = pd.read_pickle(file_name)
