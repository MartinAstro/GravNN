# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import pickle
import sigfig
import subprocess

# %%
nn_data_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\continuous_results_bennu.data'

with open(nn_data_name, 'rb') as f:
    nn_df = pickle.load(f)

file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\sh_stats_bennu_brillouin.data'

with open(file_name, 'rb') as f:
    df = pickle.load(f)

# %%
# nn_df.iloc[-1].name
# pd.Timestamp('Fri Nov 13 18:07:30 2020').to_julian_date()
nn_df.iloc[-1].name
# Out:
# 'Fri Nov 13 18:19:59 2020'

# %%
scale = 2
axes = df.plot(x=None, y=['rse_mean'],  subplots=True, layout=(1,1), figsize=(5*scale, 3.5*scale), grid=True)
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Bennu\\rse_brillioun.pdf")

# %%
scale = 2
axes = df.plot(x=None, y=['rse_mean'],  subplots=True, layout=(1,1), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Fri Nov 13 16:48:27 2020']
axes[0][0].axhline(y=data['rse_mean'], label='non-PINN') 

# data = nn_df.loc['Mon Nov  2 03:57:02 2020']
# axes[0][0].axhline(y=data['rse_mean'], label='PINN', c='r') 

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Bennu\\rse_brillioun_nn.pdf")

# %%
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\sh_stats_bennu_surface.data'

with open(file_name, 'rb') as f:
    df = pickle.load(f)

# %%
scale = 2
axes = df.plot(x=None, y=['rse_mean'],  subplots=True, layout=(1,1), figsize=(5*scale, 3.5*scale), grid=True)
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Bennu\\rse_surface.pdf")

# %%
scale = 2
axes = df.plot(x=None, y=['rse_mean'],  subplots=True, layout=(1,1), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Fri Nov 13 18:16:59 2020']
axes[0][0].axhline(y=data['rse_mean'], label='non-PINN') 

data = nn_df.loc['Fri Nov 13 18:19:59 2020']
axes[0][0].axhline(y=data['rse_mean'], label='PINN', c='r') 

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Bennu\\rse_surface_nn.pdf")
