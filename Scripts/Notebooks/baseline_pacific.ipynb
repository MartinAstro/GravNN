# %%
# %matplotlib inline

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import pickle
import sigfig
import os

# %%
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\sh_stats_reduced_grid.data'

with open(file_name, 'rb') as f:
    df = pickle.load(f)

nn_data_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\continuous_results.data'

with open(nn_data_name, 'rb') as f:
    nn_df = pickle.load(f)
os.makedirs("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Pacific\\", exist_ok=True)

# %% [markdown]
# # Map Average Stats

# %%
scale = 2
axes = df.plot(x=None, y=['rse_mean'],  subplots=True, layout=(1,1), figsize=(5*scale, 3.5*scale), grid=True)
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Pacific\\rse_map.pdf")

# %%
scale = 2
axes = df.plot(x=None, y=['rse_mean'],  subplots=True, layout=(1,1), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Mon Nov  2 02:33:21 2020']
axes[0][0].axhline(y=data['rse_mean'], label='non-PINN') 

data = nn_df.loc['Mon Nov  2 03:57:02 2020']
axes[0][0].axhline(y=data['rse_mean'], label='PINN', c='r') 

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Pacific\\rse_map_nn.pdf")

# %%
scale = 2
axes = df.plot(x=None, y=['sigma_2_mean', 'sigma_2_c_mean'],  subplots=True, layout=(2,1), figsize=(5*scale, 7*scale), grid=True)
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Pacific\\rse_features.pdf")

# %%
scale = 2
axes = df.plot(x=None, y=['sigma_2_mean', 'sigma_2_c_mean'],  subplots=True, layout=(2,1), figsize=(5*scale, 7*scale), grid=True)

data = nn_df.loc['Mon Nov  2 02:33:21 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='non-PINN') 
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='non-PINN')  

data = nn_df.loc['Mon Nov  2 03:57:02 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='PINN', c='r') 
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='PINN', c='r')  
plt.legend()


plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\Pacific\\rse_features_nn.pdf")

# %%
#pd.Timestamp(nn_df[nn_df['trajectory']== 'ReducedRandDist'][-10:].iloc[-1].name).to_julian_date()
#pd.Timestamp().to_julian_date()
nn_df[nn_df['trajectory']== 'ReducedRandDist'][-10:].iloc[-2].name
nn_df[nn_df['trajectory']== 'ReducedRandDist'][-10:].iloc[-1].name
# Out:
# 'Mon Nov  2 03:57:02 2020'

# %% [markdown]
# # Older Metrics Results

# %%
scale = 2
axes = df.plot(x=None, y=['sigma_2_mean', 'sigma_3_mean','sigma_2_c_mean', 'sigma_3_c_mean'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)

#plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics.pdf")

# %%
axes = df.plot(x=None, y=['sigma_2_mean', 'sigma_3_mean', 'sigma_2_c_mean', 'sigma_3_c_mean'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Thu Oct 29 22:11:15 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='non-PINN') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='non-PINN')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='non-PINN')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='non-PINN')  

data = nn_df.loc['Thu Oct 29 23:23:03 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='PINN', c='r') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='PINN', c='r')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='PINN', c='r')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='PINN', c='r')  

plt.legend()

# %%
axes = df.plot(x=None, y=['sigma_2_mean', 'sigma_3_mean', 'sigma_2_c_mean', 'sigma_3_c_mean'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Fri Oct 30 04:42:05 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='non-PINN-1-noise') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='non-PINN-1-noise')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='non-PINN-1-noise')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='non-PINN-1-noise')  

data = nn_df.loc['Fri Oct 30 05:46:49 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='PINN-1-noise', c='r') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='PINN-1-noise', c='r')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='PINN-1-noise', c='r')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='PINN-1-noise', c='r')  

plt.legend()

# %%
axes = df.plot(x=None, y=['sigma_2_mean', 'sigma_3_mean', 'sigma_2_c_mean', 'sigma_3_c_mean'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Fri Oct 30 07:19:59 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='non-PINN-80000 N-train 1-noise') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='non-PINN-80000 N-train 1-noise')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='non-PINN-80000 N-train 1-noise')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='non-PINN-80000 N-train 1-noise')  

data = nn_df.loc['Fri Oct 30 08:57:57 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='PINN-80000 N-train 1-noise', c='r') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='PINN-80000 N-train 1-noise', c='r')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='PINN-80000 N-train 1-noise', c='r')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='PINN-80000 N-train 1-noise', c='r')  

plt.legend()

# %%
axes = df.plot(x=None, y=['sigma_2_mean', 'sigma_3_mean', 'sigma_2_c_mean', 'sigma_3_c_mean'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Thu Oct 29 23:44:39 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='non-PINN-no-Clm-removed') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='non-PINN-no-Clm-removed')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='non-PINN-no-Clm-removed')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='non-PINN-no-Clm-removed')  

data = nn_df.loc['Fri Oct 30 00:52:15 2020']

axes[0][0].axhline(y=data['sigma_2_mean'], label='PINN-no-Clm-removed', c='r') 
axes[0][1].axhline(y=data['sigma_3_mean'], label='PINN-no-Clm-removed', c='r')  
axes[1][0].axhline(y=data['sigma_2_c_mean'], label='PINN-no-Clm-removed', c='r')  
axes[1][1].axhline(y=data['sigma_3_c_mean'], label='PINN-no-Clm-removed', c='r')  

plt.legend()

# %%
nn_df[nn_df['N_train'] == 80000][nn_df['PINN_flag'] == False][nn_df['epochs'] == 200000][nn_df['acc_noise'] == 1.0][nn_df.sigma_2_mean.notnull()][nn_df['deg_removed'] == -1].iloc[-1].name
# Out:
# 'Fri Oct 30 00:52:15 2020'

# %%
nn_df[nn_df['N_train'] == 40000][nn_df['PINN_flag'] == False][nn_df['epochs'] == 200000][nn_df['acc_noise'] == 0.0][nn_df['deg_removed'] == -1].iloc[-1].name
# Out:
# 'Thu Oct 29 23:44:39 2020'

# %%
pd.Timestamp('Thu Oct 29 23:44:39 2020').to_julian_date()
# Out:
# 2459152.489340278
