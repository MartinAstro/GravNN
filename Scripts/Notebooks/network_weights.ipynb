# %%
# %matplotlib inline

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import pickle
import os
import sigfig

# %%
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\sh_stats_full_grid.data'

with open(file_name, 'rb') as f:
    df = pickle.load(f)

nn_data_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\continuous_results.data'

with open(nn_data_name, 'rb') as f:
    nn_df = pickle.load(f)
os.makedirs("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\World\\", exist_ok=True)

# %%
nn_df.iloc[-8:]

# %%
pd.Timestamp(nn_df.iloc[-1].name).to_julian_date()
# Out:
# 2459157.095451389

# %%
file_id = "2459157.095451389"
with open(os.path.abspath('.') +"/../../Plots/"+str(file_id)+"/network.data", 'rb') as f:
    weights_init = pickle.load(f)
    biases_init = pickle.load(f)
weights_init = np.array(weights_init).reshape((-1,))
biases_init = np.array(biases_init[0]).reshape((-1,))

# %%
plt.figure(figsize=(10,7))
output = plt.hist(weights_init, 10)

# %%
plt.figure(figsize=(10,7))
output = plt.hist(biases_init, 10)
