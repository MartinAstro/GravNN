# %%
# %matplotlib inline

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import pickle
import sigfig

# %%
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\sh_stats_full_grid.data'
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\sh_stats_reduced_grid.data'

with open(file_name, 'rb') as f:
    df = pickle.load(f)

nn_data_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\continuous_results.data'

with open(nn_data_name, 'rb') as f:
    nn_df = pickle.load(f)

nn_data_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\continuous_spherical_results.data'

with open(nn_data_name, 'rb') as f:
    nn_sphere_df = pickle.load(f)

# %%
nonPINN = nn_df.loc['Tue Oct 20 19:40:07 2020']
PINN = nn_df.loc['Tue Oct 20 21:23:14 2020']
relu_nonPINN = nn_df.loc['Tue Oct 20 22:03:06 2020']
nonPINN_40 = nn_df.loc['Tue Oct 20 22:38:25 2020']

# %%
scale = 2
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  
plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Baseline.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Wed Oct 21 04:30:06 2020']

axes[0][0].axhline(y=data['percent_rel_mean'], label='epochs x2', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='epochs x2', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='epochs x2', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='epochs x2', c='r')  

data = nn_df.loc['Thu Oct 22 13:48:25 2020']

axes[0][0].axhline(y=data['percent_rel_mean'], label='epochs x0.5', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='epochs x0.5', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='epochs x0.5', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='epochs x0.5', c='g')  

data = nn_df.loc['Fri Oct 23 03:01:50 2020']

axes[0][0].axhline(y=data['percent_rel_mean'], label='epochs x10', c='y') 
axes[0][1].axhline(y=data['percent_rel_median'], label='epochs x10', c='y')  
axes[1][0].axhline(y=data['rse_mean'], label='epochs x10', c='y')  
axes[1][1].axhline(y=data['rse_median'], label='epochs x10', c='y')  


plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Epochs.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Tue Oct 20 22:38:25 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='width x2', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='width x2', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='width x2', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='width x2', c='r')  

data = nn_df.loc['Thu Oct 22 14:05:46 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='width x0.5', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='width x0.5', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='width x0.5', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='width x0.5', c='g')  
plt.legend()
nn_df[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[-1].name
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Width.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Thu Oct 22 14:42:06 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='depth x1.5', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='depth x1.5', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='depth x1.5', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='depth x1.5', c='r')  

data = nn_df.loc['Thu Oct 22 14:55:46 2020']

axes[0][0].axhline(y=data['percent_rel_mean'], label='depth x0.5', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='depth x0.5', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='depth x0.5', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='depth x0.5', c='g')  
plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Depth.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Thu Oct 22 16:20:11 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Quantity x1.5', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Quantity x1.5', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Quantity x1.5', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Quantity x1.5', c='r')  

data = nn_df.loc['Thu Oct 22 15:10:04 2020']

axes[0][0].axhline(y=data['percent_rel_mean'], label='Quantity x0.5', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Quantity x0.5', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='Quantity x0.5', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='Quantity x0.5', c='g')  
plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Data_Quantity.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Thu Oct 22 15:55:34 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Altitude 100', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Altitude 100', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Altitude 100', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Altitude 100', c='r')  

data = nn_df.loc['Thu Oct 22 15:32:56 2020']

axes[0][0].axhline(y=data['percent_rel_mean'], label='Altitude 1', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Altitude 1', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='Altitude 1', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='Altitude 1', c='g')  
plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Data_Radius.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Tue Oct 20 21:23:14 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='PINN', c='r')  

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_PINN.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Thu Oct 22 19:54:58 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Non-PINN Noise 0.01', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Non-PINN Noise 0.01', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Non-PINN Noise 0.01', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Non-PINN Noise 0.01', c='r')  

data = nn_df.loc['Thu Oct 22 19:35:19 2020']

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN Noise 0.01', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN Noise 0.01', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN Noise 0.01', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='PINN Noise 0.01', c='g')  
plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Noise_0_01.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Thu Oct 22 20:54:39 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Non-PINN Noise 0.1', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Non-PINN Noise 0.1', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Non-PINN Noise 0.1', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Non-PINN Noise 0.1', c='r') 

data = nn_df.loc['Thu Oct 22 18:16:26 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN Noise 0.1', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN Noise 0.1', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN Noise 0.1', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='PINN Noise 0.1', c='g')  

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Noise_0_1.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Thu Oct 22 21:15:46 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Non-PINN Noise 1.0', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Non-PINN Noise 1.0', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Non-PINN Noise 1.0', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Non-PINN Noise 1.0', c='r') 

data = nn_df.loc['Thu Oct 22 22:39:39 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN Noise 1.0', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN Noise 1.0', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN Noise 1.0', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='PINN Noise 1.0', c='g')  

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Noise_0_1.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Fri Oct 23 14:25:47 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Non-PINN 5000', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Non-PINN 5000', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Non-PINN 5000', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Non-PINN 5000', c='r') 

data = nn_df.loc['Fri Oct 23 14:17:00 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 5000', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 5000', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 5000', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 5000', c='g')  

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_N_5000.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Fri Oct 23 15:20:15 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Non-PINN 1000', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Non-PINN 1000', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Non-PINN 1000', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Non-PINN 1000', c='r') 

data = nn_df.loc['Fri Oct 23 15:10:45 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 1000', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 1000', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 1000', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 1000', c='g')  

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_N_1000.pdf")

# %%
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='baseline') 
axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='baseline')  
axes[1][0].axhline(y=nonPINN['rse_mean'], label='baseline')  
axes[1][1].axhline(y=nonPINN['rse_median'], label='baseline')  

data = nn_df.loc['Fri Oct 23 16:05:26 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Non-PINN All Deg', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Non-PINN All Deg', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='Non-PINN All Deg', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='Non-PINN All Deg', c='r') 

data = nn_df.loc['Fri Oct 23 17:57:04 2020'] 

axes[0][0].axhline(y=data['percent_rel_mean'], label='Non-PINN Deg 0', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='Non-PINN Deg 0', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='Non-PINN Deg 0', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='Non-PINN Deg 0', c='g') 

plt.legend()
plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_deg_removed.pdf")

# %%
nn_df[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False][nn_df['deg_removed'] == 0].iloc[0].name#.iloc[0].name
# Out:
# 'Fri Oct 23 17:57:04 2020'

# %%
# scale = 4
# axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)
# axes[0][0].axhline(y=nonPINN['percent_rel_mean'], label='non-PINN') 
# axes[0][1].axhline(y=nonPINN['percent_rel_median'], label='non-PINN')  
# axes[1][0].axhline(y=nonPINN['rse_mean'], label='non-PINN')  
# axes[1][1].axhline(y=nonPINN['rse_median'], label='non-PINN')  

# axes[0][0].axhline(y=PINN['percent_rel_mean'], label='PINN', c='r') 
# axes[0][1].axhline(y=PINN['percent_rel_median'], label='PINN', c='r')  
# axes[1][0].axhline(y=PINN['rse_mean'], label='PINN', c='r') 
# axes[1][1].axhline(y=PINN['rse_median'], label='PINN', c='r') 

# axes[0][0].axhline(y=relu_nonPINN['percent_rel_mean'], label='relu_nonPINN', c='g') 
# axes[0][1].axhline(y=relu_nonPINN['percent_rel_median'], label='relu_nonPINN', c='g')  
# axes[1][0].axhline(y=relu_nonPINN['rse_mean'], label='relu_nonPINN', c='g') 
# axes[1][1].axhline(y=relu_nonPINN['rse_median'], label='relu_nonPINN', c='g') 

# axes[0][0].axhline(y=nonPINN_40['percent_rel_mean'], label='nonPINN_40', c='y') 
# axes[0][1].axhline(y=nonPINN_40['percent_rel_median'], label='nonPINN_40', c='y')  
# axes[1][0].axhline(y=nonPINN_40['rse_mean'], label='nonPINN_40', c='y') 
# axes[1][1].axhline(y=nonPINN_40['rse_median'], label='nonPINN_40', c='y') 

#plt.legend()

# %% [markdown]
# # Pull up maps for a specified run

# %%
import subprocess
PINN_ts = nn_df.loc['Wed Oct 21 23:32:02 2020'].name
non_PINN_ts = nn_df.loc['Wed Oct 21 22:11:18 2020'].name
timestamp = non_PINN_ts
plot_directory = os.path.abspath('.') + "/../../Plots/" + str(pd.Timestamp(timestamp).to_julian_date()) + "/all.pdf"
subprocess.Popen([plot_directory],shell=True)

# %% [markdown]
# # Compression Ratio vs Accuracy

# %%
baseline = nn_df.loc['Tue Oct 20 19:40:07 2020']
params = nn_df['params']/baseline['params']
accuracy = nn_df['rse_mean']/baseline['rse_mean']

pareto = pd.concat([params, accuracy], axis=1)
pareto.plot.scatter(x='params', y='rse_mean')
# Out:
# <AxesSubplot:xlabel='params', ylabel='rse_mean'>

# %%
# Out:
# 0.0001446769286634425
