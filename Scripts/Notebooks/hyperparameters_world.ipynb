# %%
# %matplotlib inline

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import pickle
import sigfig

# %%
file_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\sh_stats_full_grid.data'

with open(file_name, 'rb') as f:
    df = pickle.load(f)
nn_data_name = 'C:\\Users\\John\\Documents\\Research\\ML_Gravity\\continuous_results.data'

with open(nn_data_name, 'rb') as f:
    nn_df = pickle.load(f)

# %%
scale =2 
axes = df.plot(x=None, y=['rel_mean', 'rel_median', 'rse_mean', 'rse_median'],  subplots=True, layout=(2,2), figsize=(5*scale, 3.5*scale), grid=True)

data = nn_df.loc['Fri Oct 23 18:46:13 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='40000', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='40000', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='40000', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='40000', c='r')  

data = nn_df.loc['Fri Oct 23 19:16:13 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='60000', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='60000', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='60000', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='60000', c='g')  

data = nn_df.loc['Fri Oct 23 20:55:54 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 40000', c='y') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 40000', c='y')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 40000', c='y')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 40000', c='y')  


data = nn_df.loc['Fri Oct 23 22:34:46 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 60000', c='b') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 60000', c='b')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 60000', c='b')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 60000', c='b')  

data = nn_df.loc['Sat Oct 24 05:57:34 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 60000', c='g') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 60000', c='g')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 60000', c='g')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 60000', c='g') 

data = nn_df.loc['Sat Oct 24 02:03:03 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 60000', c='b') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 60000', c='b')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 60000', c='b')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 60000', c='b') 

data = nn_df.loc['Sun Oct 25 00:12:01 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 259200-40-nonPINN', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 259200-40-nonPINN', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 259200-40-nonPINN', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 259200-40-nonPINN', c='r') 

data = nn_df.loc['Sun Oct 25 09:21:16 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='PINN 259200-40-PINN', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='PINN 259200-40-PINN', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='PINN 259200-40-PINN', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='PINN 259200-40-PINN', c='r') 

data = nn_df.loc['Sat Oct 24 22:01:58 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='40000-40-PINN', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='40000-40-PINN', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='40000-40-PINN', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='40000-40-PINN', c='r') 

data = nn_df.loc['Sat Oct 24 18:31:53 2020'] # Wide Network #[nn_df['N_train'] == 40000][nn_df['epochs'] == 200000][nn_df['PINN_flag'] == False].iloc[0]

axes[0][0].axhline(y=data['percent_rel_mean'], label='40000-40-nonPINN', c='r') 
axes[0][1].axhline(y=data['percent_rel_median'], label='40000-40-nonPINN', c='r')  
axes[1][0].axhline(y=data['rse_mean'], label='40000-40-nonPINN', c='r')  
axes[1][1].axhline(y=data['rse_median'], label='40000-40-nonPINN', c='r') 

plt.legend()
#plt.savefig("C:\\Users\\John\\Documents\\Research\\ML_Gravity\\Plots\\SH_Metrics_Width.pdf")

# %%
nn_df[nn_df['N_train'] == 40000][nn_df['epochs'] == 400000][nn_df['PINN_flag'] == False][nn_df['trajectory'] == 'RandomDist'].iloc[0].name
# Out:
# 'Sat Oct 24 18:31:53 2020'
